# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error

# %%
train = pd.read_csv('test_and_train_installs/train_data_encoded.csv')
test = pd.read_csv('test_and_train_installs/test_data_encoded.csv')

train2 = pd.read_csv('test_and_train_installs/train_data_encoded2.csv')
test2 = pd.read_csv('test_and_train_installs/test_data_encoded2.csv')

train3 = pd.read_csv('test_and_train_installs/train_data_encoded3.csv')
test3 = pd.read_csv('test_and_train_installs/test_data_encoded3.csv')

train4 = pd.read_csv('test_and_train_installs/train_data_encoded4.csv')
test4 = pd.read_csv('test_and_train_installs/test_data_encoded4.csv')

# %%
ref_hashes_train = train['ref_hash']
del train['ref_hash']

ref_hashes_train2 = train2['ref_hash']
del train2['ref_hash']

ref_hashes_train3 = train3['ref_hash']
del train3['ref_hash']

ref_hashes_train4 = train4['ref_hash']
del train4['ref_hash']

# %%
Xtrain, ytrain = train.iloc[:,:-1],train.iloc[:,-1]
Xtrain2, ytrain2 = train2.iloc[:,:-1],train2.iloc[:,-1]
Xtrain3, ytrain3 = train3.iloc[:,:-1],train3.iloc[:,-1]
Xtrain4, ytrain4 = train4.iloc[:,:-1],train4.iloc[:,-1]

# %%
Xtrain.fillna(0, inplace=True)

Xtrain2.fillna(0, inplace=True)

Xtrain3.fillna(0, inplace=True)

Xtrain4.fillna(0, inplace=True)

# %%
rfr = RandomForestRegressor(criterion = 'mse', max_depth = 3, n_estimators = 500, 
                            random_state = 0, verbose = 0)

# %%
# Entrenamiento
rfr.fit(Xtrain,ytrain)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=3,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
targets = pd.read_csv('target_competencia_ids.csv')

# %%
test['ref_hash'] = test['ref_hash'].astype(str) + '_sc'
test['ref_hash'] = test['ref_hash'].astype('object')

test2['ref_hash'] = test2['ref_hash'].astype(str) + '_sc'
test2['ref_hash'] = test2['ref_hash'].astype('object')

test3['ref_hash'] = test3['ref_hash'].astype(str) + '_sc'
test3['ref_hash'] = test3['ref_hash'].astype('object')

test4['ref_hash'] = test4['ref_hash'].astype(str) + '_sc'
test4['ref_hash'] = test4['ref_hash'].astype('object')

# %%
merged_test_targets = targets.merge(test, on='ref_hash', how='left').drop('obj', axis=1)
merged_test2_targets = targets.merge(test2, on='ref_hash', how='left').drop('obj', axis=1)
merged_test3_targets = targets.merge(test3, on='ref_hash', how='left').drop('obj', axis=1)
merged_test4_targets = targets.merge(test4, on='ref_hash', how='left').drop('obj', axis=1)

# %%
installs_merged = merged_test_targets.loc[merged_test_targets['ref_hash'].str.contains("_sc")]
installs_merged2 = merged_test2_targets.loc[merged_test2_targets['ref_hash'].str.contains("_sc")]
installs_merged3 = merged_test3_targets.loc[merged_test2_targets['ref_hash'].str.contains("_sc")]
installs_merged4 = merged_test4_targets.loc[merged_test2_targets['ref_hash'].str.contains("_sc")]

# %%
installs_merged['time_to_install'].fillna(259200, inplace=True)
installs_merged2['time_to_install'].fillna(259200, inplace=True)
installs_merged3['time_to_install'].fillna(259200, inplace=True)
installs_merged4['time_to_install'].fillna(259200, inplace=True)
# Out:
# /home/santiago/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
ref_hashes_installs_merged = installs_merged['ref_hash']
del installs_merged['ref_hash']

ref_hashes_installs_merged2 = installs_merged2['ref_hash']
del installs_merged2['ref_hash']

ref_hashes_installs_merged3 = installs_merged3['ref_hash']
del installs_merged3['ref_hash']

ref_hashes_installs_merged4 = installs_merged4['ref_hash']
del installs_merged4['ref_hash']

# %%
Xtest, ytest = installs_merged.iloc[:,:-1], installs_merged.iloc[:,-1]
Xtest2, ytest2 = installs_merged2.iloc[:,:-1], installs_merged2.iloc[:,-1]
Xtest3, ytest3 = installs_merged3.iloc[:,:-1], installs_merged3.iloc[:,-1]
Xtest4, ytest4 = installs_merged4.iloc[:,:-1], installs_merged4.iloc[:,-1]

# %%
Xtest.fillna(0, inplace=True)

Xtest2.fillna(0, inplace=True)

Xtest3.fillna(0, inplace=True)

Xtest4.fillna(0, inplace=True)
# Out:
# /home/santiago/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
df_ytest = pd.DataFrame(ytest)
df_ytest.reset_index(inplace=True)
del df_ytest['index']

df_ytest2 = pd.DataFrame(ytest2)
df_ytest2.reset_index(inplace=True)
del df_ytest2['index']

df_ytest3 = pd.DataFrame(ytest3)
df_ytest3.reset_index(inplace=True)
del df_ytest3['index']

df_ytest4 = pd.DataFrame(ytest4)
df_ytest4.reset_index(inplace=True)
del df_ytest4['index']

# %%
#predecir los 4k
Xtest.reset_index(inplace=True)
del Xtest['index']

Xtest2.reset_index(inplace=True)
del Xtest2['index']

Xtest3.reset_index(inplace=True)
del Xtest3['index']

Xtest4.reset_index(inplace=True)
del Xtest4['index']

# %%
# Prediccion
preds = rfr.predict(Xtest)

# %%
df_preds = pd.DataFrame(ref_hashes_installs_merged)
df_preds['preds_v1'] = preds
df_preds['ytest_v1'] = ytest
df_preds
# Out:
#                     ref_hash       preds_v1     ytest_v1
# 0     1000169251625791246_sc  131690.241205   29646.1780
# 2     1000395625957344683_sc  128548.431127  259200.0000
# 4     1003027494996471685_sc  128678.498713  247044.3875
# 6     1006670001679961544_sc  129938.265120    4844.0530
# 8     1007573308966476713_sc  128548.431127  259200.0000
# 10    1010070503877148763_sc  128548.431127  259200.0000
# 12    1010265377387765028_sc  128548.431127  259200.0000
# 14    1010531372912327058_sc  128548.431127  259200.0000
# 16    1011610998357271358_sc  128678.498713    5657.6230
# 18    1013543838965040946_sc  128548.431127  259200.0000
# 20    1014428234021750342_sc  129177.448154  193966.9900
# 22     101763096421653092_sc  128548.431127  259200.0000
# 24    1017668882534236751_sc  129559.296233   48489.5610
# 26    1017958004932387739_sc  128548.431127  259200.0000
# 28    1018126962792619181_sc  128548.431127  259200.0000
# 30    1021582875881379650_sc  128548.431127  259200.0000
# 32    1022093956983448460_sc  128548.431127  259200.0000
# 34    1022155574388897311_sc  128548.431127  259200.0000
# 36    1024792555410741306_sc  129720.923482   94639.9230
# 38    1026825193119998092_sc  128548.431127  259200.0000
# 40    1030603044158081433_sc  128537.075214    4510.4670
# 42    1030865855693267844_sc  124432.799177  156519.2470
# 44    1032938399279723623_sc  128548.431127  259200.0000
# 46    1036919443887988520_sc  128548.431127  259200.0000
# 48       1037575899869926_sc  128548.431127  259200.0000
# 50    1042912100594917197_sc  128548.431127  259200.0000
# 52     104412862089502190_sc  128548.431127  259200.0000
# 54    1048460865075142817_sc  128548.431127  259200.0000
# 56    1048487908287530052_sc  127647.078183   86390.1310
# 58    1048782984015604883_sc  128548.431127  259200.0000
# ...                      ...            ...          ...
# 8014   920133863974417940_sc  128678.498713  168443.4885
# 8016  9201763056911976665_sc  129620.120824  148985.8650
# 8018  9202591485087100048_sc  131822.369144   65771.9650
# 8020  9204600717983774215_sc  128548.431127  259200.0000
# 8022  9210211798524147977_sc  128548.431127  259200.0000
# 8024  9214306696431615228_sc  128548.431127  259200.0000
# 8026  9215274230034407241_sc  129697.495740   24898.7550
# 8028   923580934104999070_sc  128548.431127  259200.0000
# 8030   926513304015298690_sc  128548.431127  259200.0000
# 8032   928322998219934684_sc  128548.431127  259200.0000
# 8034   934102789941509295_sc  128548.431127  259200.0000
# 8036   940602545239263062_sc  128627.632396  180749.7530
# 8038   943221576691294743_sc  128678.498713    6498.0010
# 8040   947121781706964554_sc  128548.431127  259200.0000
# 8042   948984908655259886_sc  128548.431127  259200.0000
# 8044   950195972417607793_sc  128548.431127  259200.0000
# 8046   954110623376544206_sc  128496.246290   19053.9570
# 8048   954940018576714924_sc  130141.070049  187175.7230
# 8050   956704247780926402_sc  129620.120824  257100.8790
# 8052   960623204161846765_sc  127647.078183   19530.6985
# 8054   961631829441650729_sc  128548.431127  259200.0000
# 8056   962595921037755088_sc  128548.431127  259200.0000
# 8058   964658792449865522_sc  128548.431127  259200.0000
# 8060   974553511695777483_sc  128548.431127  259200.0000
# 8062    97694307709005918_sc  128548.431127  259200.0000
# 8064   977508757724050464_sc  128548.431127  259200.0000
# 8066   979880031097032355_sc  128548.431127  259200.0000
# 8068   987443249627191692_sc  128548.431127  259200.0000
# 8070   997953354533822687_sc  128548.431127  259200.0000
# 8072   998948062397755366_sc  128548.431127  259200.0000
#
# [4037 rows x 3 columns]

# %%
# Error RMSE
rmse = np.sqrt(mean_squared_error(ytest, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 114449.635901

# %%
# Entrenamiento 2
rfr.fit(Xtrain2,ytrain2)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=3,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# Prediccion 2
preds2 = rfr.predict(Xtest2)

# %%
# Error RMSE
rmse = np.sqrt(mean_squared_error(ytest2, preds2))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 116661.851239

# %%
df_preds['predictions_v2'] = preds2
df_preds['ytest_v2'] = ytest2
df_preds
# Out:
#                     ref_hash       preds_v1     ytest_v1  predictions_v2  \
# 0     1000169251625791246_sc  131690.241205   29646.1780   126512.028063
# 2     1000395625957344683_sc  128548.431127  259200.0000   126512.028063
# 8048   954940018576714924_sc  130141.070049  187175.7230   132172.647479
# 8050   956704247780926402_sc  129620.120824  257100.8790   132172.647479
# 8052   960623204161846765_sc  127647.078183   19530.6985   126512.028063
# 8054   961631829441650729_sc  128548.431127  259200.0000   138994.553681
# 8056   962595921037755088_sc  128548.431127  259200.0000   132172.647479
# 8058   964658792449865522_sc  128548.431127  259200.0000   130859.588219
# 8060   974553511695777483_sc  128548.431127  259200.0000   126512.028063
# 8062    97694307709005918_sc  128548.431127  259200.0000   126512.028063
# 8064   977508757724050464_sc  128548.431127  259200.0000   126512.028063
# 8066   979880031097032355_sc  128548.431127  259200.0000   126512.028063
# 8068   987443249627191692_sc  128548.431127  259200.0000   126512.028063
# 8070   997953354533822687_sc  128548.431127  259200.0000   126512.028063
# 8072   998948062397755366_sc  128548.431127  259200.0000   126512.028063
#
#          ytest_v2
# 0     259200.0000
# 2     259200.0000
# 4     160644.3875
# 6     259200.0000
# 8     259200.0000
# 10    259200.0000
# 12    259200.0000
# 14    259200.0000
# 16    259200.0000
# 18    259200.0000
# 20    107566.9900
# 22    259200.0000
# 24    259200.0000
# 26    183737.6570
# 28    259200.0000
# 30    221833.6590
# 32    259200.0000
# 34    259200.0000
# 36      8239.9230
# 38    259200.0000
# 40    259200.0000
# 42     70119.2470
# 44    259200.0000
# 46    259200.0000
# 48    259200.0000
# 50    259200.0000
# 52    259200.0000
# 54    259200.0000
# 56      2414.5040
# 58    259200.0000
# ...           ...
# 8014   82043.4885
# 8016   62585.8650
# 8018  259200.0000
# 8020  259200.0000
# 8022  259200.0000
# 8024  259200.0000
# 8026  259200.0000
# 8028  259200.0000
# 8030  259200.0000
# 8032  259200.0000
# 8034  259200.0000
# 8036   94349.7530
# 8038  259200.0000
# 8040  251162.4180
# 8042  259200.0000
# 8044  259200.0000
# 8046  259200.0000
# 8048  177469.1630
# 8050  170700.8790
# 8052  259200.0000
# 8054  229706.6050
# 8056  248121.8030
# 8058  182253.4560
# 8060  259200.0000
# 8062  259200.0000
# 8064  259200.0000
# 8066  259200.0000
# 8068  259200.0000
# 8070  259200.0000
# 8072  259200.0000
#
# [4037 rows x 5 columns]

# %%
# Entrenamiento 3
rfr.fit(Xtrain3,ytrain3)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=3,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# Prediccion 3
preds3 = rfr.predict(Xtest3)

# %%
# Error RMSE
rmse = np.sqrt(mean_squared_error(ytest3, preds3))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 123262.147521

# %%
df_preds['predictions_v3'] = preds3
df_preds['ytest_v3'] = ytest3
df_preds
# Out:
#                     ref_hash       preds_v1     ytest_v1  predictions_v2  \
# 0     1000169251625791246_sc  131690.241205   29646.1780   126512.028063
# 2     1000395625957344683_sc  128548.431127  259200.0000   126512.028063
# 4     1003027494996471685_sc  128678.498713  247044.3875   128759.961655
# 6     1006670001679961544_sc  129938.265120    4844.0530   126512.028063
# 8     1007573308966476713_sc  128548.431127  259200.0000   126512.028063
# 8054  229706.6050   132295.560763  143306.6050
# 8056  248121.8030   140530.242284  161721.8030
# 8058  182253.4560   129327.257723   95853.4560
# 8060  259200.0000   117626.198573  259200.0000
# 8062  259200.0000   117626.198573  259200.0000
# 8064  259200.0000   117626.198573  259200.0000
# 8066  259200.0000   117626.198573  259200.0000
# 8068  259200.0000   117626.198573  259200.0000
# 8070  259200.0000   132260.883168  184637.1910
# 8072  259200.0000   117626.198573  259200.0000
#
# [4037 rows x 7 columns]

# %%
# Entrenamiento 4
rfr.fit(Xtrain4,ytrain4)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=3,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# Prediccion 4
preds4 = rfr.predict(Xtest4)

# %%
# Error RMSE
rmse = np.sqrt(mean_squared_error(ytest4, preds4))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 107925.426470

# %%
df_preds['predictions_v4'] = preds4
df_preds['ytest_v4'] = ytest4
df_preds
# Out:
#                     ref_hash       preds_v1     ytest_v1  predictions_v2  \
# 0     1000169251625791246_sc  131690.241205   29646.1780   126512.028063
# 2     1000395625957344683_sc  128548.431127  259200.0000   126512.028063
# 4     1003027494996471685_sc  128678.498713  247044.3875   128759.961655
# 6     1006670001679961544_sc  129938.265120    4844.0530   126512.028063
# 8     1007573308966476713_sc  128548.431127  259200.0000   126512.028063
# 10    1010070503877148763_sc  128548.431127  259200.0000   126512.028063
# 12    1010265377387765028_sc  128548.431127  259200.0000   126512.028063
# 14    1010531372912327058_sc  128548.431127  259200.0000   126512.028063
# 16    1011610998357271358_sc  128678.498713    5657.6230   126512.028063
# 18    1013543838965040946_sc  128548.431127  259200.0000   126512.028063
# 20    1014428234021750342_sc  129177.448154  193966.9900   131980.197463
# 22     101763096421653092_sc  128548.431127  259200.0000   126512.028063
# 24    1017668882534236751_sc  129559.296233   48489.5610   126512.028063
# 26    1017958004932387739_sc  128548.431127  259200.0000   131208.888572
# 28    1018126962792619181_sc  128548.431127  259200.0000   126512.028063
# 30    1021582875881379650_sc  128548.431127  259200.0000   131980.197463
# 32    1022093956983448460_sc  128548.431127  259200.0000   126512.028063
# 34    1022155574388897311_sc  128548.431127  259200.0000   126512.028063
# 36    1024792555410741306_sc  129720.923482   94639.9230   132172.647479
# 38    1026825193119998092_sc  128548.431127  259200.0000   126512.028063
# 40    1030603044158081433_sc  128537.075214    4510.4670   126512.028063
# 42    1030865855693267844_sc  124432.799177  156519.2470   130924.492750
# 44    1032938399279723623_sc  128548.431127  259200.0000   126512.028063
# 46    1036919443887988520_sc  128548.431127  259200.0000   126512.028063
# 48       1037575899869926_sc  128548.431127  259200.0000   126512.028063
# 50    1042912100594917197_sc  128548.431127  259200.0000   126512.028063
# 52     104412862089502190_sc  128548.431127  259200.0000   126512.028063
# 54    1048460865075142817_sc  128548.431127  259200.0000   126512.028063
# 56    1048487908287530052_sc  127647.078183   86390.1310   132172.647479
# 58    1048782984015604883_sc  128548.431127  259200.0000   126512.028063
# ...                      ...            ...          ...             ...
# 8014   920133863974417940_sc  128678.498713  168443.4885   128722.324067
# 8072  259200.0000   117626.198573  259200.0000   134674.330077  259200.000
#
# [4037 rows x 9 columns]

# %%
df2 = pd.DataFrame(ref_hashes_installs_merged)
df2['predictions'] = (df_preds['preds_v1'] + df_preds['predictions_v2'] + df_preds['predictions_v3'] + df_preds['predictions_v4']) / 4
df2.to_csv('submit_kaggle/pred_installs.csv', index=False)

# %%
df2
# Out:
#                     ref_hash    predictions
# 0     1000169251625791246_sc  127625.699480
# 2     1000395625957344683_sc  126840.246960
# 4     1003027494996471685_sc  130902.423492
# 6     1006670001679961544_sc  127187.705458
# 8     1007573308966476713_sc  126840.246960
# 10    1010070503877148763_sc  129169.698681
# 12    1010265377387765028_sc  126840.246960
# 14    1010531372912327058_sc  126840.246960
# 16    1011610998357271358_sc  126872.763856
# 18    1013543838965040946_sc  129670.890044
# 20    1014428234021750342_sc  132173.632498
# 22     101763096421653092_sc  125546.084544
# 24    1017668882534236751_sc  127092.963237
# 26    1017958004932387739_sc  129646.881368
# 28    1018126962792619181_sc  125995.444320
# 30    1021582875881379650_sc  131620.470190
# 32    1022093956983448460_sc  129249.891500
# 34    1022155574388897311_sc  126840.246960
# 36    1024792555410741306_sc  128548.524903
# 38    1026825193119998092_sc  126840.246960
# 40    1030603044158081433_sc  126837.407982
# 42    1030865855693267844_sc  126914.455144
# 44    1032938399279723623_sc  125545.056890
# 46    1036919443887988520_sc  126013.142929
# 48       1037575899869926_sc  126009.772965
# 50    1042912100594917197_sc  129245.911397
# 52     104412862089502190_sc  126840.246960
# 54    1048460865075142817_sc  125545.056890
# 56    1048487908287530052_sc  128030.063578
# 58    1048782984015604883_sc  126840.246960
# ...                      ...            ...
# 8014   920133863974417940_sc  127425.337857
# 8016  9201763056911976665_sc  127535.894948
# 8018  9202591485087100048_sc  127658.731464
# 8020  9204600717983774215_sc  126840.246960
# 8022  9210211798524147977_sc  126077.485293
# 8024  9214306696431615228_sc  128835.566805
# 8026  9215274230034407241_sc  127127.513113
# 8028   923580934104999070_sc  126840.246960
# 8030   926513304015298690_sc  129608.032131
# 8032   928322998219934684_sc  126840.246960
# 8034   934102789941509295_sc  126840.246960
# 8036   940602545239263062_sc  130808.073753
# 8038   943221576691294743_sc  126872.763856
# 8040   947121781706964554_sc  136807.644743
# 8042   948984908655259886_sc  125529.309969
# 8044   950195972417607793_sc  128323.697911
# 8046   954110623376544206_sc  126827.200751
# 8048   954940018576714924_sc  130330.492553
# 8050   956704247780926402_sc  131937.972645
# 8052   960623204161846765_sc  126614.908724
# 8054   961631829441650729_sc  133213.137598
# 8056   962595921037755088_sc  133099.749094
# 8058   964658792449865522_sc  129541.464796
# 8060   974553511695777483_sc  125503.818836
# 8062    97694307709005918_sc  126840.246960
# 8064   977508757724050464_sc  125529.309969
# 8066   979880031097032355_sc  126840.246960
# 8068   987443249627191692_sc  125529.309969
# 8070   997953354533822687_sc  129696.381176
# 8072   998948062397755366_sc  126840.246960
#
# [4037 rows x 2 columns]
