# %%
# imports de librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

plt.style.use('default')
sns.set(style="whitegrid") # tipo de grid seaborn

# %%
#Leo la data proveniente de un csv
path_installs = 'installs.csv.gzip'
installs = pd.read_csv(path_installs, compression = 'gzip')

# %%
installs.shape
# Out:
# (3412, 18)

# %%
installs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3412 entries, 0 to 3411
# Data columns (total 18 columns):
# created               3412 non-null object
# application_id        3412 non-null int64
# ref_type              3412 non-null int64
# ref_hash              3412 non-null int64
# click_hash            0 non-null float64
# attributed            3412 non-null bool
# implicit              3412 non-null bool
# device_countrycode    3412 non-null int64
# device_brand          1047 non-null float64
# device_model          3411 non-null float64
# session_user_agent    3364 non-null object
# user_agent            1729 non-null object
# event_uuid            865 non-null object
# kind                  865 non-null object
# wifi                  1729 non-null object
# trans_id              6 non-null object
# ip_address            3412 non-null int64
# device_language       3378 non-null float64
# dtypes: bool(2), float64(4), int64(5), object(7)
# memory usage: 433.2+ KB

# %%
installs.head()
# Out:
#                    created  application_id             ref_type  \
# 0  2019-03-13 01:43:33.445               0  1891515180541284343
# 1  2019-03-13 04:58:35.078               0  1891515180541284343
# 2  2019-03-13 04:20:57.666               0  1891515180541284343
# 3  2019-03-13 04:20:57.698               0  1891515180541284343
# 4  2019-03-10 22:24:56.684               0  1891515180541284343
#
#               ref_hash  click_hash  attributed  implicit   device_countrycode  \
# 0  8464844987297247076         NaN       False     False  6333597102633388268
# 1  3250564871270161533         NaN       False     False  6333597102633388268
# 2  7953318831018100268         NaN       False      True  6333597102633388268
# 3  7953318831018100268         NaN       False     False  6333597102633388268
# 4  8355110941557237501         NaN       False      True  6333597102633388268
#
#    device_brand  device_model                 session_user_agent user_agent  \
# 0  3.083059e+17  4.445252e+18                                NaN        NaN
# 1  3.083059e+17  4.445252e+18                                NaN        NaN
# 2  5.137992e+17  6.026543e+18  HasOffers Mobile AppTracking v1.0        NaN
# 3  5.137992e+17  6.026543e+18                                NaN        NaN
# 4  1.083369e+18  7.876612e+18  HasOffers Mobile AppTracking v1.0        NaN
#
#                              event_uuid  kind wifi trans_id  \
# 0                                   NaN   NaN  NaN      NaN
# 1                                   NaN   NaN  NaN      NaN
# 2  0bfa9b4c-e07a-4522-b32d-138e3165ac98  Open  NaN      NaN
# 3                                   NaN   NaN  NaN      NaN
# 4  8f235a8c-41bf-4399-b33d-c41577c949b0  Open  NaN      NaN
#
#             ip_address  device_language
# 0  5529284367937637301              NaN
# 1  6098022721363533304              NaN
# 2  4636407223847323867     3.301378e+18
# 3  4636407223847323867              NaN
# 4   685400811232710215     3.301378e+18

# %%
installs.describe()
# Out:
#        application_id      ref_type      ref_hash  click_hash  \
# count     3412.000000  3.412000e+03  3.412000e+03         0.0
# mean        10.247655  1.736533e+18  4.598202e+18         NaN
# std          6.016194  1.936976e+17  2.663828e+18         NaN
# min          0.000000  1.494519e+18  4.958527e+15         NaN
# 25%          7.000000  1.494519e+18  2.268353e+18         NaN
# 50%          9.000000  1.891515e+18  4.603807e+18         NaN
# 75%         10.000000  1.891515e+18  6.912404e+18         NaN
# max         36.000000  1.891515e+18  9.218934e+18         NaN
#
#        device_countrycode  device_brand  device_model    ip_address  \
# count        3.412000e+03  1.047000e+03  3.411000e+03  3.412000e+03
# mean         4.764401e+18  1.877864e+18  4.245276e+18  4.562040e+18
# std          1.678051e+18  1.886461e+18  2.620844e+18  2.683422e+18
# min          2.970471e+18  3.083059e+17  5.112505e+16  7.118754e+15
# 25%          2.970471e+18  3.083059e+17  2.331947e+18  2.249197e+18
# 50%          6.333597e+18  2.208835e+18  2.983638e+18  4.436113e+18
# 75%          6.333597e+18  2.523246e+18  6.882415e+18  7.017564e+18
# max          6.333597e+18  9.169527e+18  9.222450e+18  9.221950e+18
#
#        device_language
# count     3.378000e+03
# mean      4.915828e+18
# std       2.477019e+18
# min       1.101539e+17
# 25%       3.301378e+18
# 50%       3.301378e+18
# 75%       6.977049e+18
# max       9.028383e+18

# %%
# Damos formato a la fecha.
installs['timestamp_format'] = pd.to_datetime(installs['created'])

# Agrego columna fecha
installs['date'] = installs['timestamp_format'].dt.date
# Agrego columna de mes.
installs['month'] = installs['timestamp_format'].dt.month
# Agrego columna nombre dia.
installs['weekday_name'] = installs['timestamp_format'].dt.weekday_name
# Agrego columna numero dia.
installs['day'] = installs['timestamp_format'].dt.day
# Agrego columna de horas
installs['hour'] = installs['timestamp_format'].dt.hour

# %%
# fecha minima
installs['timestamp_format'].min()
# Out:
# Timestamp('2019-03-05 00:00:38.219000')

# %%
# fecha maxima
installs['timestamp_format'].max()
# Out:
# Timestamp('2019-03-13 23:54:00.526000')

# %%
#Agrego columna para contar
installs.insert(1, 'counter', 1)

# %%
installs.groupby('attributed')['application_id'].count()
# Out:
# attributed
# False    3412
# Name: application_id, dtype: int64

# %%
# utilizo la columna 'application_id' para contar xq tiene valor no nulo en todos los registros
installs_por_dia = installs.groupby('date')['application_id'].count()
g = installs_por_dia.plot()
g.set_xlabel("Dia", fontsize=18)
g.set_ylabel("Cantidad de Installs", fontsize=18)

g.get_figure().set_size_inches(18.5, 10.5, forward=True)
g.get_figure().savefig('img/cant_installs_por_dia.png')

# %%
### Numero de installs realizados por dia.
# Filtro los dias 12 y 13 para que justo haya 1 semana de data
tabla_semanal = installs.loc[installs['day'] < 12,:]

for_heatmap_hr_day = tabla_semanal.pivot_table(index='hour', columns='weekday_name', values='counter', aggfunc='sum')

g = sns.heatmap(for_heatmap_hr_day , linewidths=.5, cmap="YlGnBu") # annot=True
g.set_title("Numero de installs segun Hora y Dia", fontsize=22)
g.set_xlabel("Dia",fontsize=18)
g.set_ylabel("Hora", fontsize=18)


g.get_figure().set_size_inches(18.5, 10.5, forward=True)
g.get_figure().savefig('img/installs_hr_dia.png')
# Out:
# /home/german/.local/lib/python3.5/site-packages/pandas/core/computation/check.py:19: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.6.1
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
# utilizo la columna 'application_id' para contar xq tiene valor no nulo en todos los registros
usuarios = installs.groupby('ref_hash')['application_id'].agg('count').sort_values(ascending=False)[:10]
g = sns.barplot(x=usuarios.values, y=usuarios.index, palette='rainbow', orient='h')
g.set_xlabel('Cantidad de installs')
g.set_ylabel('ID Usuario')
g.set_title('Top 10 usuarios que mas installs hicieron')


g.get_figure().set_size_inches(18.5, 10.5, forward=True)
g.get_figure().savefig('img/top_10_usuarios_installs.png')

# %%
# utilizo la columna 'application_id' para contar xq tiene valor no nulo en todos los registros
usuarios = installs.groupby('application_id')['application_id'].agg('count').sort_values(ascending=False)[:10]
g = sns.barplot(x=usuarios.values, y=usuarios.index, palette='rainbow', orient='h')
g.set_xlabel('Cantidad de installs')
g.set_ylabel('ID App')
g.set_title('Top 10 apps que mas installs tuvieron')


g.get_figure().set_size_inches(18.5, 10.5, forward=True)
g.get_figure().savefig('img/top_10_apps_installs.png')

# %%
# utilizo la columna 'application_id' para contar xq tiene valor no nulo en todos los registros
usuarios = installs.groupby('device_countrycode')['application_id'].agg('count').sort_values(ascending=False)[:10]
g = sns.barplot(x=usuarios.values, y=usuarios.index, palette='rainbow', orient='h')
g.set_xlabel('Cantidad de installs')
g.set_ylabel('Pais')
g.set_title('Installs por Pais')


g.get_figure().set_size_inches(18.5, 10.5, forward=True)
g.get_figure().savefig('img/installs_por_pais.png')

# %%
# utilizo la columna 'application_id' para contar xq tiene valor no nulo en todos los registros
usuarios = installs.groupby('device_brand')['application_id'].agg('count').sort_values(ascending=False)
g = sns.barplot(x=usuarios.values, y=usuarios.index, palette='rainbow', orient='h')
g.set_xlabel('Cantidad de installs')
g.set_ylabel('ID Brand')
g.set_title('Installs por Brand')


g.get_figure().set_size_inches(18.5, 10.5, forward=True)
g.get_figure().savefig('img/top_10_brand_installs.png')

# %%
# utilizo la columna 'counter' para contar xq tiene valor no nulo en todos los registros
usuarios = installs.groupby('device_language')['counter'].agg('count').sort_values(ascending=False)
g = sns.barplot(x=usuarios.values, y=usuarios.index, palette='rainbow', orient='h')
g.set_xlabel('Cantidad de installs')
g.set_ylabel('ID Idioma')
g.set_title('Installs por Idioma')


g.get_figure().set_size_inches(18.5, 10.5, forward=True)
g.get_figure().savefig('img/top_10_language_installs.png')

# %%
installs.groupby(['device_brand', 'user_agent'])['application_id'].count()
# Out:
# device_brand  user_agent
# 3.083059e+17  Dalvik/1.6.0 (Linux; U; Android 4.1.2; GT-I8262B Build/JZO54K)                   2
#               Dalvik/1.6.0 (Linux; U; Android 4.1.2; GT-I8552B Build/JZO54K)                   2
#               Dalvik/1.6.0 (Linux; U; Android 4.1.2; GT-N8000 Build/JZO54K)                    1
#               Dalvik/1.6.0 (Linux; U; Android 4.2.2; GT-I9063T Build/JDQ39)                    1
#               Dalvik/1.6.0 (Linux; U; Android 4.3; SM-G3502T Build/JLS36C)                     2
#               Dalvik/1.6.0 (Linux; U; Android 4.3; SM-G7102T Build/JLS36C)                     1
#               Dalvik/1.6.0 (Linux; U; Android 4.4.2; GT-P5210 Build/KOT49H)                    1
#               Dalvik/1.6.0 (Linux; U; Android 4.4.2; GT-S5312C Build/KOT49H)                   2
#               Dalvik/1.6.0 (Linux; U; Android 4.4.2; SM-G110B Build/KOT49H)                    1
#               Dalvik/1.6.0 (Linux; U; Android 4.4.2; SM-T535 Build/KOT49H)                     1
#               Dalvik/1.6.0 (Linux; U; Android 4.4.4; SM-G316M Build/KTU84P)                    2
#               Dalvik/1.6.0 (Linux; U; Android 4.4.4; SM-G530H Build/KTU84P)                    3
#               Dalvik/1.6.0 (Linux; U; Android 4.4.4; SM-T113NU Build/KTU84P)                   2
#               Dalvik/1.6.0 (Linux; U; Android 4.4.4; SM-T116BU Build/KTU84P)                   4
#               Dalvik/1.6.0 (Linux; U; Android 4.4.4; SM-T560 Build/KTU84P)                     2
#               Dalvik/2.1.0 (Linux; U; Android 22; SM-J200M Build/LMY47X)                       1
#               Dalvik/2.1.0 (Linux; U; Android 5.0.2; SM-A300M Build/LRX22G)                    1
#               Dalvik/2.1.0 (Linux; U; Android 5.0.2; SM-G360BT Build/LRX22G)                   3
#               Dalvik/2.1.0 (Linux; U; Android 5.0.2; SM-G360F Build/LRX22G)                    1
#               Dalvik/2.1.0 (Linux; U; Android 5.0.2; SM-G530BT Build/LRX22G)                   5
#               Dalvik/2.1.0 (Linux; U; Android 5.0; SM-G900M Build/LRX21T)                      1
#               Dalvik/2.1.0 (Linux; U; Android 5.0; SM-N900W8 Build/LRX21V)                     1
#               Dalvik/2.1.0 (Linux; U; Android 5.1.1; SM-G531BT Build/LMY48B)                   2
#               Dalvik/2.1.0 (Linux; U; Android 5.1.1; SM-G531H Build/LMY48B)                    7
#               Dalvik/2.1.0 (Linux; U; Android 5.1.1; SM-J105B Build/LMY47V)                   12
#               Dalvik/2.1.0 (Linux; U; Android 5.1.1; SM-J105M Build/LMY47V)                    1
#               Dalvik/2.1.0 (Linux; U; Android 5.1.1; SM-J111M Build/LMY47V)                    3
#               Dalvik/2.1.0 (Linux; U; Android 5.1.1; SM-J120H Build/LMY47V)                    8
#               Dalvik/2.1.0 (Linux; U; Android 5.1.1; SM-J200BT Build/LMY47X)                   3
#               Dalvik/2.1.0 (Linux; U; Android 5.1.1; SM-J320FN Build/LMY47V)                   1
#                                                                                               ..
# 3.849490e+18  Dalvik/2.1.0 (Linux; U; Android 5.1; ZTE Blade L5 Build/LMY47I)                  1
# 4.371308e+18  Dalvik/2.1.0 (Linux; U; Android 5.1.1; Lenovo A6020l36 Build/LMY47V)             2
#               Dalvik/2.1.0 (Linux; U; Android 5.1; Lenovo A7010a48 Build/LMY47D)               1
#               Dalvik/2.1.0 (Linux; U; Android 6.0.1; Lenovo A6020l36 Build/MMB29M)             2
#               Dalvik/2.1.0 (Linux; U; Android 6.0.1; Lenovo TB-X103F Build/LenovoTB-X103F)     1
#               Dalvik/2.1.0 (Linux; U; Android 7.0; Lenovo K33b36 Build/NRD90N)                 1
# 4.994101e+18  Dalvik/2.1.0 (Linux; U; Android 5.0.2; S455 Build/LRX22G)                        4
# 5.189983e+18  Dalvik/2.1.0 (Linux; U; Android 7.0; A102 Build/NRD90M)                          1
# 5.588755e+18  Dalvik/2.1.0 (Linux; U; Android 9; ONEPLUS A6013 Build/PKQ1.180716.001)          1
# 5.645692e+18  Dalvik/1.6.0 (Linux; U; Android 7.0; A985P Build/KOT49H)                         2
#               Dalvik/2.1.0 (Linux; U; Android 6.0; moto g6 Build/MRA58K)                       1
# 6.111647e+18  Dalvik/2.1.0 (Linux; U; Android 6.0; Positivo Twist M Build/MRA58K)              1
#               Dalvik/2.1.0 (Linux; U; Android 7.0; Positivo Slim Build/NRD90M)                 2
# 6.538562e+18  Dalvik/2.1.0 (Linux; U; Android 5.0; ASUS_Z00AD Build/LRX21V)                    1
#               Dalvik/2.1.0 (Linux; U; Android 5.1.1; ASUS_X013D Build/LMY47V)                  3
#               Dalvik/2.1.0 (Linux; U; Android 5.1; ASUS_Z00VD Build/LMY47I)                    2
#               Dalvik/2.1.0 (Linux; U; Android 6.0.1; ASUS_A007 Build/MMB29P)                   2
#               Dalvik/2.1.0 (Linux; U; Android 6.0.1; ASUS_Z00UD Build/MMB29P)                  1
#               Dalvik/2.1.0 (Linux; U; Android 6.0.1; ASUS_Z00XS Build/MMB29P)                  2
#               Dalvik/2.1.0 (Linux; U; Android 7.0; ASUS_X008DC Build/NRD90M)                   1
#               Dalvik/2.1.0 (Linux; U; Android 7.1.1; ASUS_X00DDA Build/NMF26F)                 3
#               Dalvik/2.1.0 (Linux; U; Android 7.1.1; ASUS_Z01MD Build/NMF26F)                  1
#               Dalvik/2.1.0 (Linux; U; Android 8.0.0; ASUS_Z012DC Build/OPR1.170623.026)        1
#               Dalvik/2.1.0 (Linux; U; Android 8.0.0; ASUS_Z017DC Build/OPR1.170623.026)        1
#               Dalvik/2.1.0 (Linux; U; Android 8.0.0; ASUS_Z01HDA Build/OPR1.170623.026)        1
#               Dalvik/2.1.0 (Linux; U; Android 8.1.0; ASUS_X00LD Build/OPM1.171019.011)         6
#               Dalvik/2.1.0 (Linux; U; Android 8.1.0; ASUS_X00TDB Build/OPM1)                   1
# 7.855186e+18  Dalvik/2.1.0 (Linux; U; Android 7.0; Kylin_5.0S Build/NRD90M)                    1
# 8.285870e+18  Dalvik/2.1.0 (Linux; U; Android 7.0; X203-B Build/NRD90M)                        3
# 9.169527e+18  Dalvik/2.1.0 (Linux; U; Android 6.0; Bluboo Maya Max Build/MRA58K)               1
# Name: application_id, Length: 282, dtype: int64

# %%
installs.groupby(['ref_hash', 'device_brand'])['application_id'].count().sort_values()
# Out:
# ref_hash             device_brand
# 4958526679100225     3.083059e+17    1
# 5611184548012188441  2.208835e+18    1
# 5634738659911451938  5.951325e+18    1
# 5651666841804012468  3.083059e+17    1
# 5653412983131455761  6.538562e+18    1
# 5673486627602156791  3.083059e+17    1
# 5675338478942110054  3.083059e+17    1
# 5682487104945590494  5.951325e+18    1
# 5687561920157939968  3.083059e+17    1
# 5702519445523682055  2.523246e+18    1
# 5703857289308913755  5.951325e+18    1
# 5730093385249626197  2.208835e+18    1
# 5742061314162685631  5.645692e+18    1
# 5754691161969059178  2.523246e+18    1
# 5755584711199594053  3.083059e+17    1
# 5755621990732289986  2.208835e+18    1
# 5769490111157488831  2.987569e+18    1
# 5783355789750736502  3.083059e+17    1
# 5798442016718083629  2.208835e+18    1
# 5801652291849635098  3.083059e+17    1
# 5601466796317352138  3.812621e+18    1
# 5805521595277705698  3.083059e+17    1
# 5592222636977314940  2.208835e+18    1
# 5566372061916199893  2.208835e+18    1
# 5262628146672581353  3.083059e+17    1
# 5288312075363369444  2.208835e+18    1
# 5297293407935670013  2.208835e+18    1
# 5324222246833153329  3.083059e+17    1
# 5354188736353595030  3.083059e+17    1
# 5358574926846728502  3.083059e+17    1
#                                     ..
# 5217881686976870289  5.951325e+18    2
# 7175972769155842743  3.083059e+17    2
# 7201600423615607613  3.083059e+17    2
# 5152529264026804406  2.208835e+18    2
# 1519234846777481690  5.951325e+18    2
# 7244773004863372289  3.228516e+18    2
# 7384853215310088561  3.083059e+17    2
# 1504646378544548143  3.083059e+17    2
# 1509635473974904053  5.951325e+18    2
# 7283951349175423097  3.083059e+17    2
# 7322284846287966871  2.208835e+18    2
# 5129780403184854828  5.137992e+17    2
# 1476839687527464951  5.951325e+18    2
# 3136598168332379862  3.083059e+17    2
# 7283069842470184895  5.951325e+18    2
# 7317134744729963099  3.083059e+17    2
# 3133434105055991331  3.083059e+17    2
# 7249349646978996230  2.208835e+18    2
# 2457547163021424058  2.523246e+18    3
# 1332624341050561368  3.083059e+17    3
# 4587898421740190562  2.208835e+18    3
# 4603142710878547974  2.987569e+18    3
# 1838099903940931904  2.987569e+18    3
# 5716316704073038128  2.987569e+18    3
# 3293250764324184935  2.208835e+18    3
# 808602801225309575   3.083059e+17    3
# 8209340170282049305  6.538562e+18    3
# 2807966731127456435  8.285870e+18    3
# 5208834946313176321  2.208835e+18    4
# 3272750442824629569  3.083059e+17    4
# Name: application_id, Length: 849, dtype: int64
